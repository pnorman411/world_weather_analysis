# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
import gmaps
import requests
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %%
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(20)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
        
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | coquimbo
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | te anau
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | college
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | katsuura
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | katobu
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | parabel
# Processing Record 20 of Set 1 | sept-iles
# Processing Record 21 of Set 1 | west bay
# Processing Record 22 of Set 1 | yei
# Processing Record 23 of Set 1 | lata
# Processing Record 24 of Set 1 | klaksvik
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | aksarka
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | kaitangata
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | mani
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | namatanai
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | kavaratti
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | lambarene
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | christchurch
# Processing Record 42 of Set 1 | oxelosund
# Processing Record 43 of Set 1 | sur
# Processing Record 44 of Set 1 | esmeraldas
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | bonfim
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | tshikapa
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | yar-sale
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | saint-augustin
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | koslan
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | haines junction
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | port arthur
# Processing Record 15 of Set 2 | marsh harbour
# Processing Record 16 of Set 2 | port blair
# Processing Record 17 of Set 2 | bairiki
# Processing Record 18 of Set 2 | oriximina
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | sao gabriel da cachoeira
# Processing Record 22 of Set 2 | coihaique
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | touros
# Processing Record 25 of Set 2 | yuzhno-sukhokumsk
# Processing Record 26 of Set 2 | chicama
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | viedma
# Processing Record 30 of Set 2 | zhigansk
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 2 | minab
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | njombe
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | muroto
# Processing Record 43 of Set 2 | necochea
# Processing Record 44 of Set 2 | acapulco
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | ust-tsilma
# Processing Record 47 of Set 2 | ankazoabo
# Processing Record 48 of Set 2 | katha
# City not found. Skipping...
# Processing Record 49 of Set 2 | hangu
# Processing Record 50 of Set 2 | ayan
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | san quintin
# Processing Record 7 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 3 | lakeside
# Processing Record 9 of Set 3 | tomatlan
# Processing Record 10 of Set 3 | barabai
# Processing Record 11 of Set 3 | antalya
# Processing Record 12 of Set 3 | port hardy
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | narsaq
# Processing Record 16 of Set 3 | heihe
# Processing Record 17 of Set 3 | ixtapa
# Processing Record 18 of Set 3 | mackay
# Processing Record 19 of Set 3 | rundu
# Processing Record 20 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 21 of Set 3 | half moon bay
# Processing Record 22 of Set 3 | lindi
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | teguise
# Processing Record 25 of Set 3 | rawson
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | japura
# Processing Record 28 of Set 3 | kropotkin
# Processing Record 29 of Set 3 | pandan
# Processing Record 30 of Set 3 | tuatapere
# Processing Record 31 of Set 3 | mandurah
# Processing Record 32 of Set 3 | sete lagoas
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | stykkisholmur
# Processing Record 35 of Set 3 | codrington
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | sillod
# Processing Record 38 of Set 3 | winona
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | pundaguitan
# Processing Record 41 of Set 3 | hervey bay
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | san policarpo
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | kruisfontein
# Processing Record 46 of Set 3 | bilma
# Processing Record 47 of Set 3 | santa maria
# Processing Record 48 of Set 3 | xudat
# Processing Record 49 of Set 3 | namwala
# Processing Record 50 of Set 3 | tarakan
# Processing Record 1 of Set 4 | nizhniy odes
# Processing Record 2 of Set 4 | cabedelo
# Processing Record 3 of Set 4 | bapatla
# Processing Record 4 of Set 4 | kiunga
# Processing Record 5 of Set 4 | lavrentiya
# Processing Record 6 of Set 4 | dargaville
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 9 of Set 4 | saint combs
# City not found. Skipping...
# Processing Record 10 of Set 4 | xiangxiang
# Processing Record 11 of Set 4 | komsomolskiy
# Processing Record 12 of Set 4 | hurghada
# Processing Record 13 of Set 4 | fort nelson
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | aswan
# Processing Record 18 of Set 4 | negrar
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | okahandja
# Processing Record 21 of Set 4 | chapeco
# Processing Record 22 of Set 4 | labuan
# Processing Record 23 of Set 4 | mahebourg
# Processing Record 24 of Set 4 | yellowknife
# Processing Record 25 of Set 4 | morbach
# Processing Record 26 of Set 4 | tura
# Processing Record 27 of Set 4 | itarema
# Processing Record 28 of Set 4 | mondlo
# Processing Record 29 of Set 4 | margate
# Processing Record 30 of Set 4 | gorontalo
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | chokurdakh
# Processing Record 33 of Set 4 | coari
# Processing Record 34 of Set 4 | fauske
# Processing Record 35 of Set 4 | sorland
# Processing Record 36 of Set 4 | yerofey pavlovich
# Processing Record 37 of Set 4 | fairbanks
# Processing Record 38 of Set 4 | izhma
# Processing Record 39 of Set 4 | takoradi
# Processing Record 40 of Set 4 | alofi
# Processing Record 41 of Set 4 | cap malheureux
# Processing Record 42 of Set 4 | hilo
# Processing Record 43 of Set 4 | victoria
# Processing Record 44 of Set 4 | clyde river
# Processing Record 45 of Set 4 | puerto ayora
# Processing Record 46 of Set 4 | hastings
# Processing Record 47 of Set 4 | cusset
# Processing Record 48 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 4 | shingu
# Processing Record 50 of Set 4 | jacareacanga
# Processing Record 1 of Set 5 | arlit
# Processing Record 2 of Set 5 | rio grande
# Processing Record 3 of Set 5 | huntingdon
# Processing Record 4 of Set 5 | aurangabad
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | darnah
# Processing Record 7 of Set 5 | pacifica
# Processing Record 8 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 5 | beringovskiy
# Processing Record 10 of Set 5 | ancud
# Processing Record 11 of Set 5 | marienburg
# Processing Record 12 of Set 5 | souillac
# Processing Record 13 of Set 5 | grindavik
# Processing Record 14 of Set 5 | nhulunbuy
# Processing Record 15 of Set 5 | caucaia
# Processing Record 16 of Set 5 | pangody
# Processing Record 17 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 5 | puerto ayacucho
# Processing Record 19 of Set 5 | kutum
# Processing Record 20 of Set 5 | sorong
# Processing Record 21 of Set 5 | soyo
# Processing Record 22 of Set 5 | longyearbyen
# Processing Record 23 of Set 5 | cabra
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | bathsheba
# Processing Record 27 of Set 5 | ponta delgada
# Processing Record 28 of Set 5 | asayita
# City not found. Skipping...
# Processing Record 29 of Set 5 | santa vitoria do palmar
# Processing Record 30 of Set 5 | avarua
# Processing Record 31 of Set 5 | pacific grove
# Processing Record 32 of Set 5 | airai
# Processing Record 33 of Set 5 | isangel
# Processing Record 34 of Set 5 | nichinan
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | naryan-mar
# Processing Record 37 of Set 5 | paita
# Processing Record 38 of Set 5 | camopi
# Processing Record 39 of Set 5 | poum
# Processing Record 40 of Set 5 | kimbe
# Processing Record 41 of Set 5 | jagdalpur
# Processing Record 42 of Set 5 | bethel
# Processing Record 43 of Set 5 | hualmay
# Processing Record 44 of Set 5 | charlestown
# Processing Record 45 of Set 5 | dongsheng
# Processing Record 46 of Set 5 | odweyne
# Processing Record 47 of Set 5 | lerwick
# Processing Record 48 of Set 5 | ust-nera
# Processing Record 49 of Set 5 | pisco
# Processing Record 50 of Set 5 | ambad
# Processing Record 1 of Set 6 | eureka
# Processing Record 2 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 6 | shahrud
# Processing Record 4 of Set 6 | oktyabrskiy
# Processing Record 5 of Set 6 | camacha
# Processing Record 6 of Set 6 | horodnytsya
# Processing Record 7 of Set 6 | kiruna
# Processing Record 8 of Set 6 | north platte
# Processing Record 9 of Set 6 | georgetown
# Processing Record 10 of Set 6 | flinders
# Processing Record 11 of Set 6 | polovinnoye
# Processing Record 12 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 13 of Set 6 | coolum beach
# Processing Record 14 of Set 6 | lorengau
# Processing Record 15 of Set 6 | maumere
# Processing Record 16 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 6 | inhambane
# Processing Record 18 of Set 6 | xining
# Processing Record 19 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 20 of Set 6 | kieta
# Processing Record 21 of Set 6 | paraiso
# Processing Record 22 of Set 6 | chapais
# Processing Record 23 of Set 6 | gao
# Processing Record 24 of Set 6 | spring hill
# Processing Record 25 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 6 | plouzane
# Processing Record 27 of Set 6 | changping
# Processing Record 28 of Set 6 | vestmannaeyjar
# Processing Record 29 of Set 6 | santa isabel do rio negro
# Processing Record 30 of Set 6 | pemangkat
# Processing Record 31 of Set 6 | raudeberg
# Processing Record 32 of Set 6 | udachnyy
# Processing Record 33 of Set 6 | quepos
# Processing Record 34 of Set 6 | kologriv
# Processing Record 35 of Set 6 | hami
# Processing Record 36 of Set 6 | avera
# Processing Record 37 of Set 6 | atar
# Processing Record 38 of Set 6 | aklavik
# Processing Record 39 of Set 6 | jumla
# Processing Record 40 of Set 6 | dingle
# Processing Record 41 of Set 6 | meulaboh
# Processing Record 42 of Set 6 | vanimo
# Processing Record 43 of Set 6 | hamilton
# Processing Record 44 of Set 6 | nouadhibou
# Processing Record 45 of Set 6 | copala
# Processing Record 46 of Set 6 | lakselv
# Processing Record 47 of Set 6 | axim
# Processing Record 48 of Set 6 | abrud
# Processing Record 49 of Set 6 | sao joao de pirabas
# Processing Record 50 of Set 6 | yerbogachen
# Processing Record 1 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 7 | muravlenko
# Processing Record 3 of Set 7 | araouane
# Processing Record 4 of Set 7 | parksville
# Processing Record 5 of Set 7 | emerald
# Processing Record 6 of Set 7 | hofn
# Processing Record 7 of Set 7 | midsalip
# Processing Record 8 of Set 7 | groningen
# Processing Record 9 of Set 7 | laguna
# Processing Record 10 of Set 7 | ugoofaaru
# Processing Record 11 of Set 7 | dong hoi
# Processing Record 12 of Set 7 | visnes
# Processing Record 13 of Set 7 | mindelo
# Processing Record 14 of Set 7 | juneau
# Processing Record 15 of Set 7 | autun
# Processing Record 16 of Set 7 | mastic beach
# Processing Record 17 of Set 7 | dabakala
# Processing Record 18 of Set 7 | vardo
# Processing Record 19 of Set 7 | san jose
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | carauari
# Processing Record 22 of Set 7 | nagato
# Processing Record 23 of Set 7 | sabana grande de boya
# Processing Record 24 of Set 7 | saint-joseph
# Processing Record 25 of Set 7 | salinopolis
# Processing Record 26 of Set 7 | geraldton
# Processing Record 27 of Set 7 | ambon
# Processing Record 28 of Set 7 | havre-saint-pierre
# Processing Record 29 of Set 7 | thompson
# Processing Record 30 of Set 7 | slave lake
# Processing Record 31 of Set 7 | jiazi
# Processing Record 32 of Set 7 | constitucion
# Processing Record 33 of Set 7 | sabha
# Processing Record 34 of Set 7 | hambantota
# Processing Record 35 of Set 7 | keti bandar
# Processing Record 36 of Set 7 | santo domingo
# Processing Record 37 of Set 7 | sajanan
# Processing Record 38 of Set 7 | sann
# Processing Record 39 of Set 7 | kagalnik
# Processing Record 40 of Set 7 | mount isa
# Processing Record 41 of Set 7 | we
# City not found. Skipping...
# Processing Record 42 of Set 7 | nemuro
# Processing Record 43 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 7 | erzin
# Processing Record 46 of Set 7 | brae
# Processing Record 47 of Set 7 | stromness
# Processing Record 48 of Set 7 | sunndalsora
# Processing Record 49 of Set 7 | palauig
# Processing Record 50 of Set 7 | taoudenni
# Processing Record 1 of Set 8 | zagorje ob savi
# Processing Record 2 of Set 8 | abu samrah
# Processing Record 3 of Set 8 | san ignacio
# Processing Record 4 of Set 8 | vao
# Processing Record 5 of Set 8 | lebu
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | tuy hoa
# Processing Record 8 of Set 8 | north bend
# Processing Record 9 of Set 8 | nador
# Processing Record 10 of Set 8 | yantal
# Processing Record 11 of Set 8 | jeremie
# Processing Record 12 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 8 | gavle
# Processing Record 14 of Set 8 | filingue
# Processing Record 15 of Set 8 | severo-kurilsk
# Processing Record 16 of Set 8 | bandarbeyla
# Processing Record 17 of Set 8 | homer
# Processing Record 18 of Set 8 | rio gallegos
# Processing Record 19 of Set 8 | tabou
# Processing Record 20 of Set 8 | russell
# Processing Record 21 of Set 8 | natal
# Processing Record 22 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 8 | chimoio
# Processing Record 24 of Set 8 | kanniyakumari
# Processing Record 25 of Set 8 | kahului
# Processing Record 26 of Set 8 | shimoda
# Processing Record 27 of Set 8 | port lincoln
# Processing Record 28 of Set 8 | dawlatabad
# Processing Record 29 of Set 8 | tyukalinsk
# Processing Record 30 of Set 8 | doka
# Processing Record 31 of Set 8 | riaba
# City not found. Skipping...
# Processing Record 32 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 8 | kamenka
# Processing Record 34 of Set 8 | marawi
# Processing Record 35 of Set 8 | saint-pierre
# Processing Record 36 of Set 8 | broken hill
# Processing Record 37 of Set 8 | ulaanbaatar
# Processing Record 38 of Set 8 | tortoli
# Processing Record 39 of Set 8 | basco
# Processing Record 40 of Set 8 | wawa
# Processing Record 41 of Set 8 | rocha
# Processing Record 42 of Set 8 | provideniya
# Processing Record 43 of Set 8 | hammerfest
# Processing Record 44 of Set 8 | shancheng
# Processing Record 45 of Set 8 | mataram
# Processing Record 46 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 8 | tigil
# Processing Record 48 of Set 8 | shangzhi
# Processing Record 49 of Set 8 | sao miguel
# Processing Record 50 of Set 8 | samana
# Processing Record 1 of Set 9 | mnogovershinnyy
# Processing Record 2 of Set 9 | nizhneudinsk
# Processing Record 3 of Set 9 | talnakh
# Processing Record 4 of Set 9 | jinchang
# Processing Record 5 of Set 9 | bukachacha
# Processing Record 6 of Set 9 | tibati
# Processing Record 7 of Set 9 | dicabisagan
# Processing Record 8 of Set 9 | kharitonovo
# Processing Record 9 of Set 9 | mezen
# Processing Record 10 of Set 9 | luanda
# Processing Record 11 of Set 9 | puerto suarez
# Processing Record 12 of Set 9 | riyadh
# Processing Record 13 of Set 9 | savelugu
# Processing Record 14 of Set 9 | turayf
# Processing Record 15 of Set 9 | beloha
# Processing Record 16 of Set 9 | yulara
# Processing Record 17 of Set 9 | badarganj
# Processing Record 18 of Set 9 | kuruman
# Processing Record 19 of Set 9 | rafaela
# Processing Record 20 of Set 9 | sao jose da coroa grande
# Processing Record 21 of Set 9 | ambilobe
# Processing Record 22 of Set 9 | volsk
# Processing Record 23 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 25 of Set 9 | palmer
# Processing Record 26 of Set 9 | sisimiut
# Processing Record 27 of Set 9 | colares
# Processing Record 28 of Set 9 | tabas
# Processing Record 29 of Set 9 | nelson bay
# Processing Record 30 of Set 9 | skibbereen
# Processing Record 31 of Set 9 | broome
# Processing Record 32 of Set 9 | paracuru
# Processing Record 33 of Set 9 | zatoka
# Processing Record 34 of Set 9 | derzhavinsk
# Processing Record 35 of Set 9 | katherine
# Processing Record 36 of Set 9 | yumen
# Processing Record 37 of Set 9 | moulmeingyun
# City not found. Skipping...
# Processing Record 38 of Set 9 | anadyr
# Processing Record 39 of Set 9 | calabozo
# Processing Record 40 of Set 9 | kupang
# Processing Record 41 of Set 9 | novopokrovka
# Processing Record 42 of Set 9 | ati
# Processing Record 43 of Set 9 | uruzgan
# Processing Record 44 of Set 9 | zaozerne
# Processing Record 45 of Set 9 | todos santos
# Processing Record 46 of Set 9 | chuy
# Processing Record 47 of Set 9 | portland
# Processing Record 48 of Set 9 | olga
# Processing Record 49 of Set 9 | guanica
# Processing Record 50 of Set 9 | hasaki
# Processing Record 1 of Set 10 | salisbury
# Processing Record 2 of Set 10 | mozelos
# Processing Record 3 of Set 10 | torbay
# Processing Record 4 of Set 10 | labuhan
# Processing Record 5 of Set 10 | indramayu
# Processing Record 6 of Set 10 | lexington
# Processing Record 7 of Set 10 | ponta do sol
# Processing Record 8 of Set 10 | bundaberg
# Processing Record 9 of Set 10 | gigmoto
# Processing Record 10 of Set 10 | mandalgovi
# Processing Record 11 of Set 10 | san cristobal
# Processing Record 12 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 10 | ayorou
# Processing Record 14 of Set 10 | chokwe
# Processing Record 15 of Set 10 | biltine
# Processing Record 16 of Set 10 | bilibino
# Processing Record 17 of Set 10 | takikawa
# Processing Record 18 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 10 | khash
# Processing Record 22 of Set 10 | santa luzia
# Processing Record 23 of Set 10 | port-gentil
# Processing Record 24 of Set 10 | maltahohe
# Processing Record 25 of Set 10 | sosua
# Processing Record 26 of Set 10 | sinnamary
# Processing Record 27 of Set 10 | chara
# Processing Record 28 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 10 | maceio
# Processing Record 30 of Set 10 | rjukan
# Processing Record 31 of Set 10 | kloulklubed
# Processing Record 32 of Set 10 | quatre cocos
# Processing Record 33 of Set 10 | kyra
# Processing Record 34 of Set 10 | helsinki
# Processing Record 35 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 36 of Set 10 | ostrov
# Processing Record 37 of Set 10 | moose factory
# Processing Record 38 of Set 10 | mecca
# Processing Record 39 of Set 10 | talas
# Processing Record 40 of Set 10 | honningsvag
# Processing Record 41 of Set 10 | byron bay
# Processing Record 42 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 43 of Set 10 | yeppoon
# Processing Record 44 of Set 10 | ocampo
# Processing Record 45 of Set 10 | karratha
# Processing Record 46 of Set 10 | idritsa
# Processing Record 47 of Set 10 | lagoa
# Processing Record 48 of Set 10 | menongue
# Processing Record 49 of Set 10 | camaguey
# Processing Record 50 of Set 10 | santiago tuxtla
# Processing Record 1 of Set 11 | prachatice
# Processing Record 2 of Set 11 | ahipara
# Processing Record 3 of Set 11 | vega de alatorre
# Processing Record 4 of Set 11 | namibe
# Processing Record 5 of Set 11 | temiscaming
# Processing Record 6 of Set 11 | izoplit
# Processing Record 7 of Set 11 | joshimath
# Processing Record 8 of Set 11 | tulum
# Processing Record 9 of Set 11 | makubetsu
# Processing Record 10 of Set 11 | kishtwar
# Processing Record 11 of Set 11 | mlonggo
# Processing Record 12 of Set 11 | lompoc
# Processing Record 13 of Set 11 | longyan
# Processing Record 14 of Set 11 | los llanos de aridane
# Processing Record 15 of Set 11 | gillette
# Processing Record 16 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 11 | conde
# Processing Record 18 of Set 11 | kailaras
# Processing Record 19 of Set 11 | bairnsdale
# Processing Record 20 of Set 11 | poltavka
# Processing Record 21 of Set 11 | badaojiang
# City not found. Skipping...
# Processing Record 22 of Set 11 | rakovski
# Processing Record 23 of Set 11 | villeneuve-sur-lot
# Processing Record 24 of Set 11 | neiafu
# Processing Record 25 of Set 11 | berlevag
# Processing Record 26 of Set 11 | sakakah
# Processing Record 27 of Set 11 | turtas
# Processing Record 28 of Set 11 | luganville
# Processing Record 29 of Set 11 | vylgort
# City not found. Skipping...
# Processing Record 30 of Set 11 | alamor
# Processing Record 31 of Set 11 | tabuny
# Processing Record 32 of Set 11 | flin flon
# Processing Record 33 of Set 11 | bardiyah
# Processing Record 34 of Set 11 | manosque
# Processing Record 35 of Set 11 | aybak
# City not found. Skipping...
# Processing Record 36 of Set 11 | barra do corda
# Processing Record 37 of Set 11 | mahibadhoo
# Processing Record 38 of Set 11 | ankang
# Processing Record 39 of Set 11 | maxixe
# Processing Record 40 of Set 11 | mancheral
# Processing Record 41 of Set 11 | temyasovo
# Processing Record 42 of Set 11 | asau
# Processing Record 43 of Set 11 | bowen
# Processing Record 44 of Set 11 | glyadyanskoye
# Processing Record 45 of Set 11 | samarai
# Processing Record 46 of Set 11 | tiznit
# Processing Record 47 of Set 11 | vanderhoof
# Processing Record 48 of Set 11 | thanh hoa
# Processing Record 49 of Set 11 | pangoa
# Processing Record 50 of Set 11 | goderich
# Processing Record 1 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 12 | sao filipe
# Processing Record 3 of Set 12 | kuryk
# Processing Record 4 of Set 12 | banda aceh
# Processing Record 5 of Set 12 | richmond
# Processing Record 6 of Set 12 | camocim
# Processing Record 7 of Set 12 | adre
# Processing Record 8 of Set 12 | bubaque
# Processing Record 9 of Set 12 | nchelenge
# Processing Record 10 of Set 12 | lobito
# Processing Record 11 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 12 of Set 12 | ostrovnoy
# Processing Record 13 of Set 12 | lundazi
# Processing Record 14 of Set 12 | madison
# Processing Record 15 of Set 12 | toamasina
# Processing Record 16 of Set 12 | san juan
# Processing Record 17 of Set 12 | pangnirtung
# Processing Record 18 of Set 12 | vaitape
# Processing Record 19 of Set 12 | horuphav
# Processing Record 20 of Set 12 | turan
# Processing Record 21 of Set 12 | mingguang
# Processing Record 22 of Set 12 | dharchula
# Processing Record 23 of Set 12 | stornoway
# Processing Record 24 of Set 12 | usinsk
# Processing Record 25 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 12 | vredendal
# Processing Record 27 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 28 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 29 of Set 12 | sibi
# Processing Record 30 of Set 12 | kuusamo
# Processing Record 31 of Set 12 | puerto del rosario
# Processing Record 32 of Set 12 | iquitos
# Processing Record 33 of Set 12 | ceyhan
# Processing Record 34 of Set 12 | khani
# Processing Record 35 of Set 12 | comodoro rivadavia
# Processing Record 36 of Set 12 | karpuninskiy
# City not found. Skipping...
# Processing Record 37 of Set 12 | alliston
# Processing Record 38 of Set 12 | kangaatsiaq
# Processing Record 39 of Set 12 | ketou
# Processing Record 40 of Set 12 | de aar
# Processing Record 41 of Set 12 | lodwar
# Processing Record 42 of Set 12 | saint-jean-de-la-ruelle
# Processing Record 43 of Set 12 | halifax
# Processing Record 44 of Set 12 | saint anthony
# Processing Record 45 of Set 12 | caledon
# Processing Record 46 of Set 12 | superior
# Processing Record 47 of Set 12 | ngunguru
# Processing Record 48 of Set 12 | ilulissat
# Processing Record 49 of Set 12 | davila
# Processing Record 50 of Set 12 | wageningen
# Processing Record 1 of Set 13 | chibombo
# Processing Record 2 of Set 13 | strathpeffer
# Processing Record 3 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 4 of Set 13 | opuwo
# Processing Record 5 of Set 13 | josefina
# Processing Record 6 of Set 13 | skegness
# Processing Record 7 of Set 13 | ustye
# Processing Record 8 of Set 13 | vila velha
# Processing Record 9 of Set 13 | kostomuksha
# Processing Record 10 of Set 13 | heinola
# Processing Record 11 of Set 13 | aguas formosas
# Processing Record 12 of Set 13 | taos
# Processing Record 13 of Set 13 | ginda
# Processing Record 14 of Set 13 | qaqortoq
# Processing Record 15 of Set 13 | west wendover
# Processing Record 16 of Set 13 | husavik
# Processing Record 17 of Set 13 | koprivnica
# Processing Record 18 of Set 13 | zonalnoye
# City not found. Skipping...
# Processing Record 19 of Set 13 | alice springs
# Processing Record 20 of Set 13 | cayenne
# Processing Record 21 of Set 13 | kidal
# Processing Record 22 of Set 13 | khuzdar
# Processing Record 23 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 13 | rucar
# Processing Record 25 of Set 13 | springbok
# Processing Record 26 of Set 13 | borogontsy
# Processing Record 27 of Set 13 | preili
# Processing Record 28 of Set 13 | ukiah
# Processing Record 29 of Set 13 | buinsk
# Processing Record 30 of Set 13 | walvis bay
# Processing Record 31 of Set 13 | meadow lake
# Processing Record 32 of Set 13 | teya
# Processing Record 33 of Set 13 | salmon arm
# Processing Record 34 of Set 13 | fuyang
# Processing Record 35 of Set 13 | queenstown
# Processing Record 36 of Set 13 | leningradskiy
# Processing Record 37 of Set 13 | kibala
# Processing Record 38 of Set 13 | kindu
# Processing Record 39 of Set 13 | las vegas
# Processing Record 40 of Set 13 | la ronge
# Processing Record 41 of Set 13 | tripoli
# Processing Record 42 of Set 13 | sechura
# Processing Record 43 of Set 13 | havoysund
# Processing Record 44 of Set 13 | semlac
# Processing Record 45 of Set 13 | turukhansk
# Processing Record 46 of Set 13 | palu
# Processing Record 47 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 13 | grand forks
# Processing Record 49 of Set 13 | sola
# Processing Record 50 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 1 of Set 14 | staryy nadym
# Processing Record 2 of Set 14 | kapit
# Processing Record 3 of Set 14 | canutama
# Processing Record 4 of Set 14 | padang
# Processing Record 5 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 14 | abnub
# Processing Record 7 of Set 14 | high prairie
# Processing Record 8 of Set 14 | ketchikan
# Processing Record 9 of Set 14 | oran
# Processing Record 10 of Set 14 | nakusp
# Processing Record 11 of Set 14 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 12 of Set 14 | bronnoysund
# Processing Record 13 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 14 | redding
# Processing Record 15 of Set 14 | kungurtug
# Processing Record 16 of Set 14 | puerto escondido
# Processing Record 17 of Set 14 | caraquet
# Processing Record 18 of Set 14 | ndele
# Processing Record 19 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 14 | nyurba
# Processing Record 21 of Set 14 | smirnykh
# Processing Record 22 of Set 14 | anan
# Processing Record 23 of Set 14 | sistranda
# Processing Record 24 of Set 14 | egvekinot
# Processing Record 25 of Set 14 | mayo
# Processing Record 26 of Set 14 | zhangjiakou
# Processing Record 27 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 28 of Set 14 | shache
# Processing Record 29 of Set 14 | hay river
# Processing Record 30 of Set 14 | sebu
# Processing Record 31 of Set 14 | yongan
# Processing Record 32 of Set 14 | shuangyang
# Processing Record 33 of Set 14 | daru
# Processing Record 34 of Set 14 | puerto baquerizo moreno
# Processing Record 35 of Set 14 | maragogi
# Processing Record 36 of Set 14 | katubao
# Processing Record 37 of Set 14 | vestmanna
# Processing Record 38 of Set 14 | durban
# Processing Record 39 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 40 of Set 14 | adigeni
# Processing Record 41 of Set 14 | panormos
# Processing Record 42 of Set 14 | sakaiminato
# Processing Record 43 of Set 14 | rumoi
# Processing Record 44 of Set 14 | tazovskiy
# Processing Record 45 of Set 14 | bay roberts
# Processing Record 46 of Set 14 | sao francisco
# Processing Record 47 of Set 14 | buzmeyin
# Processing Record 48 of Set 14 | daud khel
# Processing Record 49 of Set 14 | nipawin
# Processing Record 50 of Set 14 | boshnyakovo
# Processing Record 1 of Set 15 | iberia
# Processing Record 2 of Set 15 | rincon
# Processing Record 3 of Set 15 | bideford
# Processing Record 4 of Set 15 | santa fe
# Processing Record 5 of Set 15 | agadez
# Processing Record 6 of Set 15 | vysokogornyy
# Processing Record 7 of Set 15 | mtwara
# Processing Record 8 of Set 15 | richards bay
# Processing Record 9 of Set 15 | kailua
# Processing Record 10 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 15 | mutis
# Processing Record 12 of Set 15 | banes
# Processing Record 13 of Set 15 | tautira
# Processing Record 14 of Set 15 | nantucket
# Processing Record 15 of Set 15 | umea
# Processing Record 16 of Set 15 | edd
# Processing Record 17 of Set 15 | pendleton
# Processing Record 18 of Set 15 | high level
# Processing Record 19 of Set 15 | coahuayana
# Processing Record 20 of Set 15 | aykhal
# Processing Record 21 of Set 15 | oussouye
# Processing Record 22 of Set 15 | oranjemund
# Processing Record 23 of Set 15 | jakar
# Processing Record 24 of Set 15 | mocuba
# Processing Record 25 of Set 15 | boyolangu
# Processing Record 26 of Set 15 | winton
# Processing Record 27 of Set 15 | akonolinga
# Processing Record 28 of Set 15 | paamiut
# Processing Record 29 of Set 15 | jardim
# Processing Record 30 of Set 15 | limbdi
# Processing Record 31 of Set 15 | yamada
# Processing Record 32 of Set 15 | biak
# Processing Record 33 of Set 15 | port moresby
# Processing Record 34 of Set 15 | kosai
# Processing Record 35 of Set 15 | aukra
# Processing Record 36 of Set 15 | ampanihy
# Processing Record 37 of Set 15 | ossora
# Processing Record 38 of Set 15 | faya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 670

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cherskiy  68.7500  161.3000     -1.39        99          92
# 1        Coquimbo -29.9533  -71.3436     55.13        87           0
# 2     Tuktoyaktuk  69.4541 -133.0374     21.20        79          90
# 3         Te Anau -45.4167  167.7167     66.29        52          89
# 4  Ribeira Grande  38.5167  -28.7000     69.66        85          60
# 5          Albany  42.6001  -73.9662     39.81        79          12
# 6           Bluff -46.6000  168.3333     58.84        76          93
# 7          Dikson  73.5069   80.5464      5.34        97          97
# 8           Vaini -21.2000 -175.2000     77.16       100          90
# 9         College  64.8569 -147.8028     24.75        89          90
#
#    Wind Speed Country                 Date Current Description
# 0        5.32      RU  2021-11-08 04:38:01     overcast clouds
# 1        3.44      CL  2021-11-08 04:38:01           clear sky
# 2        4.61      CA  2021-11-08 04:38:01          light snow
# 3        4.27      NZ  2021-11-08 04:38:02     overcast clouds
# 4       22.28      PT  2021-11-08 04:36:13       broken clouds
# 5        3.49      US  2021-11-08 04:37:55          few clouds
# 6       12.01      NZ  2021-11-08 04:36:17     overcast clouds
# 7        3.09      RU  2021-11-08 04:38:03     overcast clouds
# 8        5.75      TO  2021-11-08 04:36:21       moderate rain
# 9        3.44      US  2021-11-08 04:38:03          light snow

# %%
# reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cherskiy      RU  68.7500  161.3000     -1.39        99          92
# 1        Coquimbo      CL -29.9533  -71.3436     55.13        87           0
# 2     Tuktoyaktuk      CA  69.4541 -133.0374     21.20        79          90
# 3         Te Anau      NZ -45.4167  167.7167     66.29        52          89
# 4  Ribeira Grande      PT  38.5167  -28.7000     69.66        85          60
# 5          Albany      US  42.6001  -73.9662     39.81        79          12
# 6           Bluff      NZ -46.6000  168.3333     58.84        76          93
# 7          Dikson      RU  73.5069   80.5464      5.34        97          97
# 8           Vaini      TO -21.2000 -175.2000     77.16       100          90
# 9         College      US  64.8569 -147.8028     24.75        89          90
#
#    Wind Speed Current Description
# 0        5.32     overcast clouds
# 1        3.44           clear sky
# 2        4.61          light snow
# 3        4.27     overcast clouds
# 4       22.28       broken clouds
# 5        3.49          few clouds
# 6       12.01     overcast clouds
# 7        3.09     overcast clouds
# 8        5.75       moderate rain
# 9        3.44          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
